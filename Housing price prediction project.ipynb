# %%
#Importing All Libraries:

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
import sklearn
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.ensemble import GradientBoostingRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
df_train=pd.read_csv("train.csv")
#pd.set_option('display.max_columns',None)
df_train.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2007        WD         Normal     128000
# 1     10   2007        WD         Normal     268000
# 2      6   2007        WD         Normal     269790
# 3      1   2010       COD         Normal     190000
# 4      6   2009        WD         Normal     215000
#
# [5 rows x 81 columns]

# %%
df_test=pd.read_csv("test.csv")
#pd.set_option('display.max_rows',None)
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2007        WD         Normal
# 1       0      8    2009       COD        Abnorml
# 2       0      6    2009        WD         Normal
# 3       0      7    2009        WD         Normal
# 4       0      1    2008        WD         Normal
#
# [5 rows x 80 columns]

# %%
print("No: of Rows and columns for Train data set : ",df_train.shape)
print("No: of Rows and columns for Test data set  : ",df_test.shape)
# Out:
# No: of Rows and columns for Train data set :  (1168, 81)
# No: of Rows and columns for Test data set  :  (292, 80)

# %% [markdown]
#  Observation from above code it states that in test data set we have missing columns. Target column "SalePrice" is missing in test data set.Now lets combine both the train & test datasets. Concat them as one dataset for our analysis. So that it is easy for doing EDA and other processes. Later at time of model building we can split them again.

# %%
df_train["dataset_type"]="Train"
df_test["dataset_type"]="Test"

# %%
df_concat=pd.concat([df_train,df_test],ignore_index=True)

# %%
df_concat.shape
# Out:
# (1460, 82)

# %%
df_concat["dataset_type"].value_counts()
# Out:
# Train    1168
# Test      292
# Name: dataset_type, dtype: int64

# %%
df_concat.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
#                  ...
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         581
# dataset_type        2
# Length: 82, dtype: int64

# %%
df_concat.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice        float64
# dataset_type      object
# Length: 82, dtype: object

# %%
df_concat.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN    NaN         NaN       0      2   2007
# 1         Lvl    AllPub  ...    NaN    NaN         NaN       0     10   2007
# 2         Lvl    AllPub  ...    NaN    NaN         NaN       0      6   2007
# 3         Lvl    AllPub  ...    NaN  MnPrv         NaN       0      1   2010
# 4         Lvl    AllPub  ...    NaN    NaN         NaN       0      6   2009
#
#   SaleType  SaleCondition  SalePrice  dataset_type
# 0       WD         Normal   128000.0         Train
# 1       WD         Normal   268000.0         Train
# 2       WD         Normal   269790.0         Train
# 3      COD         Normal   190000.0         Train
# 4       WD         Normal   215000.0         Train
#
# [5 rows x 82 columns]

# %% [markdown]
# We can observe that there are Nan values in the dataset after concatinating. So lets handle them first.

# %%
df_concat.isnull().sum()[df_concat.isnull().sum()>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# SalePrice        292
# dtype: int64

# %% [markdown]
# We can notice that some null values after merging the 2 datasets. Lets fix it first.

# %%
df_concat.select_dtypes(include='object').isnull().sum()[df_concat.select_dtypes(include='object').isnull().sum()>0]
# Out:
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# We have filtered the Objects columns alone with null values

# %%
df_concat.select_dtypes(include=['int64','float']).isnull().sum()[df_concat.select_dtypes(include=['int64','float']).isnull().sum()>0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# SalePrice      292
# dtype: int64

# %% [markdown]
# We have filtered the Numeric columns alone with null values

# %%
df_concat['LotFrontage'].value_counts().sum()
# Out:
# 1201

# %%
df_concat['LotFrontage'].median()
# Out:
# 69.0

# %%
df_concat['MasVnrArea'].median()
# Out:
# 0.0

# %%
df_concat['LotFrontage'] = df_concat['LotFrontage'].replace(np.nan, df_concat['LotFrontage'].median())
df_concat['MasVnrArea'] = df_concat['MasVnrArea'].replace(np.nan, df_concat['MasVnrArea'].median())

# %%
df_concat['GarageYrBlt']=df_concat['GarageYrBlt'].fillna(0)
df_concat['GarageYrBlt'] = df_concat['GarageYrBlt'].astype(int)

# %% [markdown]
# First Numerical columns have been handled for removing Null Values in above block of codes.

# %%
print(df_concat.Alley.value_counts())
print('')
print(df_concat.Street.value_counts())
print(" ")
print(df_concat.Utilities.value_counts())
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
#
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64
#
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
df_concat = df_concat.drop(['Alley','Street','Utilities','PoolQC','Fence','MiscFeature','Id'],axis='columns')

# %% [markdown]
# Removing some columns as mentioned above since class values in each columns are one sided i.e. more than 95% of data in that columns are of same value or with only one data class

# %%
df_concat.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df_concat.MasVnrType.fillna('None',inplace=True)
df_concat.BsmtQual.fillna('TA',inplace=True)
df_concat.BsmtCond.fillna('TA',inplace=True)
df_concat.BsmtExposure.fillna('No',inplace=True)
df_concat.BsmtFinType1.fillna('Unf',inplace=True)
df_concat.BsmtFinType2.fillna('Unf',inplace=True)
df_concat.GarageType.fillna('Attchd',inplace=True)
df_concat.GarageFinish.fillna('Unf',inplace=True)
df_concat.GarageQual.fillna('TA',inplace=True)
df_concat.GarageCond.fillna('TA',inplace=True)
df_concat.Electrical.fillna('SBrkr',inplace=True)
df_concat.FireplaceQu.fillna('Gd',inplace=True)

# %%
df_concat.select_dtypes(include='object').isnull().sum()[df_concat.select_dtypes(include='object').isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
# Check if there are any duplicate values in the dataset

df_concat[df_concat.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, LotShape, LandContour, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, dataset_type]
# Index: []
#
# [0 rows x 75 columns]

# %% [markdown]
# In above set of block of codes we have replaced or removed the null values for object columns

# %%
df_concat.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# 0         120       RL         69.0     4928      IR1         Lvl    Inside
# 1          20       RL         95.0    15865      IR1         Lvl    Inside
# 2          60       RL         92.0     9920      IR1         Lvl   CulDSac
# 3          20       RL        105.0    11751      IR1         Lvl    Inside
# 4          20       RL         69.0    16635      IR1         Lvl       FR2
#
#   LandSlope Neighborhood Condition1  ... 3SsnPorch ScreenPorch PoolArea  \
# 0       Gtl      NPkVill       Norm  ...         0           0        0
# 1       Mod        NAmes       Norm  ...         0         224        0
# 2       Gtl      NoRidge       Norm  ...         0           0        0
# 3       Gtl       NWAmes       Norm  ...         0           0        0
# 4       Gtl       NWAmes       Norm  ...         0           0        0
#
#    MiscVal  MoSold  YrSold  SaleType SaleCondition SalePrice dataset_type
# 0        0       2    2007        WD        Normal  128000.0        Train
# 1        0      10    2007        WD        Normal  268000.0        Train
# 2        0       6    2007        WD        Normal  269790.0        Train
# 3        0       1    2010       COD        Normal  190000.0        Train
# 4        0       6    2009        WD        Normal  215000.0        Train
#
# [5 rows x 75 columns]

# %% [markdown]
# ## EDA

# %%
df_train["SalePrice"].hist(grid=True,color='red')
plt.title("SalePrice ranges of Houses")
plt.show()

# %%
plt.subplots(figsize=(8,6))
sns.countplot(df_concat['YrSold'])
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='count'>

# %% [markdown]
# The number of sales in the year 2009 is having the maxium number of sales.

# %%
plt.figure(figsize=(15,8))
sns.barplot(x="MSSubClass",y="SalePrice",data=df_concat)
#plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2-STORY 1946 & NEWER is the kind of class which has the higher sale price.

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="MSZoning",y="SalePrice",data=df_concat)
#plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Floating Village Residential (FV) has the higher value of sales

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="LotShape",y="SalePrice",data=df_concat)
#plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="LandContour",y="SalePrice",data=df_concat)
#plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="LotConfig",y="SalePrice",data=df_concat)
#plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="LandSlope",y="SalePrice",data=df_concat)
#plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Neighborhood",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# North Ridge is the Physical locations within Ames city limits has the higher count of saleprices

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Condition1",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# PosA Adjacent to postive off-site feature RRNe Within 200' of East-West Railroad these are the two most valued Proximity to various conditions

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Condition2",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BldgType",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# TwnhsE Townhouse End Unit 1Fam Single-family Detached are the one which has higher rates of sales

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="HouseStyle",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2.5Fin Two and one-half story: 2nd level finished has the higher count of salesprice

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="OverallQual",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  Very Excellent class value has the higher quality and hence higher price values. and the graph shows the slope as the quality increases the Sales Price increases.

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="OverallCond",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Very Excellent class value has the higher quality and hence higher price values. and the graph shows the slope as the quality increases the Sales Price increases.

# %%
plt.figure(figsize=(22,6))
sns.barplot(x="YearBuilt",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  Year 2010 and year 1892 has the max price in sales

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="YearRemodAdd",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Remodeling is done in year 2010 is of max counts

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="RoofStyle",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="RoofMatl",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Exterior1st",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Exterior2nd",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="MasVnrType",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="ExterQual",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Foundation",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BsmtQual",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BsmtCond",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BsmtFinType1",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BsmtFinType2",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Heating",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="HeatingQC",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="CentralAir",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="Electrical",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BsmtFullBath",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BsmtHalfBath",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="FullBath",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="HalfBath",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="BedroomAbvGr",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="KitchenQual",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="TotRmsAbvGrd",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.barplot(x="GarageYrBlt",y="SalePrice",data=df_concat)
plt.xticks(rotation=90)
plt.show()

# %%
df_concat["GarageCars"].hist(grid=True,color='blue')
plt.title("Size of garage in car capacity")
plt.show()

# %%
df_concat["GarageArea"].hist(grid=True,color='blue')
plt.title("Size of garage in square feet")
plt.show()

# %%
df_concat["GarageQual"].hist(grid=True,color='blue')
plt.title("Garage quality")
plt.show()

# %%
df_concat["PavedDrive"].hist(grid=True,color='blue')
plt.title("Paved driveway")
plt.show()

# %%
df_concat["WoodDeckSF"].hist(grid=True,color='blue')
plt.title("Wood deck area in square feet")
plt.show()

# %%
df_concat["PavedDrive"].hist(grid=True,color='blue')
plt.title("Paved driveway")
plt.show()

# %%
df_concat["OpenPorchSF"].hist(grid=True,color='blue')
plt.title("Open porch area in square feet")
plt.show()

# %%
df_concat["EnclosedPorch"].hist(grid=True,color='blue')
plt.title("Enclosed porch area in square feet")
plt.show()

# %%
df_concat["3SsnPorch"].hist(grid=True,color='blue')
plt.title("Three season porch area in square feet")
plt.show()

# %%
df_concat["ScreenPorch"].hist(grid=True,color='blue')
plt.title("Screen porch area in square feet")
plt.show()

# %%
df_concat["3SsnPorch"].hist(grid=True,color='blue')
plt.title("Three season porch area in square feet")
plt.show()

# %%
df_concat["PoolArea"].hist(grid=True,color='blue')
plt.title("Pool area in square feet")
plt.show()

# %%
df_concat["MoSold"].hist(grid=True,color='blue')
plt.title("Month Sold (MM)")
plt.show()

# %%
df_concat["YrSold"].hist(grid=True,color='blue')
plt.title("Year sold (YYYY)")
plt.show()

# %%
sns.catplot(x='SaleType',y='SalePrice',data=df_concat)

# %%
sns.catplot(x='SaleCondition',y='SalePrice',data = df_concat.sort_values("SalePrice", ascending = False), height = 5, aspect = 3)

# %%
sns.swarmplot(x="GarageFinish", y="GarageCars",hue='GarageQual', data=df_concat)

plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]), [Text(0, 0, 'RFn'), Text(1, 0, 'Unf'), Text(2, 0, 'Fin')])

# %%
sns.lmplot(x ='HouseStyle', y ='YearBuilt',fit_reg = False, hue = 'SaleType',data = df_concat)

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x="YrSold", y="YearBuilt", data=df_concat, jitter=.08)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='YearBuilt'>

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x="HouseStyle", y="OverallQual", data=df_concat, jitter=.1)
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='OverallQual'>

# %%
corr_mat=df_concat.corr()
corr_mat
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.356718 -0.139781     0.032628    -0.059316
# LotFrontage     -0.356718     1.000000  0.304522     0.234812    -0.053281
# LotArea         -0.139781     0.304522  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.234812  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.053281 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.116685  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.083348  0.013788     0.550684     0.073741
# MasVnrArea       0.023573     0.178469  0.103321     0.407252    -0.125694
# BsmtFinSF1      -0.069836     0.214367  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.042463  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.124098 -0.002618     0.308159    -0.136841
# TotalBsmtSF     -0.238518     0.363472  0.260833     0.537808    -0.171098
# 1stFlrSF        -0.251758     0.413773  0.299475     0.476224    -0.144203
# 2ndFlrSF         0.307886     0.072388  0.050986     0.295493     0.028942
# LowQualFinSF     0.046474     0.037469  0.004779    -0.030429     0.025494
# GrLivArea        0.074853     0.368007  0.263116     0.593007    -0.079686
# BsmtFullBath     0.003491     0.090343  0.158155     0.111098    -0.054942
# BsmtHalfBath    -0.002333    -0.006979  0.048046    -0.040150     0.117821
# FullBath         0.131608     0.180534  0.126031     0.550600    -0.194149
# HalfBath         0.177354     0.047222  0.014259     0.273458    -0.060769
# BedroomAbvGr    -0.023438     0.236840  0.119690     0.101676     0.012980
# KitchenAbvGr     0.281721    -0.004905 -0.017784    -0.183882    -0.087001
# TotRmsAbvGrd     0.040380     0.320518  0.190015     0.427452    -0.057583
# Fireplaces      -0.045569     0.233221  0.271364     0.396765    -0.023820
# GarageYrBlt     -0.080997     0.099196  0.072599     0.288998    -0.006515
# GarageCars      -0.040110     0.269539  0.154871     0.600671    -0.185758
# GarageArea      -0.098672     0.323511  0.180403     0.562022    -0.151521
# WoodDeckSF      -0.012579     0.075542  0.171698     0.238923    -0.003334
# OpenPorchSF     -0.006100     0.137014  0.084774     0.308819    -0.032589
# EnclosedPorch   -0.012037     0.010287 -0.018340    -0.113937     0.070356
# 3SsnPorch       -0.043825     0.061945  0.020423     0.030371     0.025504
# ScreenPorch     -0.026030     0.037655  0.043160     0.064886     0.054811
# PoolArea         0.008283     0.180819  0.077672     0.065166    -0.001985
# MiscVal         -0.007683    -0.000255  0.038068    -0.031406     0.068777
# MoSold          -0.013585     0.010451  0.001205     0.070815    -0.003511
# YrSold          -0.021407     0.006380 -0.014261    -0.027347     0.043950
# SalePrice       -0.060775     0.323828  0.249499     0.789185    -0.065642
#
#                YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.027850      0.040581    0.023573   -0.069836   -0.065649
# LotFrontage     0.116685      0.083348    0.178469    0.214367    0.042463
# LotArea         0.014228      0.013788    0.103321    0.214103    0.111170
# OverallQual     0.572323      0.550684    0.407252    0.239666   -0.059119
# OverallCond    -0.375983      0.073741   -0.125694   -0.046231    0.040229
# YearBuilt       1.000000      0.592855    0.311600    0.249503   -0.049107
# YearRemodAdd    0.592855      1.000000    0.176529    0.128451   -0.067759
# MasVnrArea      0.311600      0.176529    1.000000    0.261256   -0.071330
# BsmtFinSF1      0.249503      0.128451    0.261256    1.000000   -0.050117
# BsmtFinSF2     -0.049107     -0.067759   -0.071330   -0.050117    1.000000
# BsmtUnfSF       0.149040      0.181133    0.113862   -0.495251   -0.209294
# TotalBsmtSF     0.391452      0.291066    0.360067    0.522396    0.104810
# 1stFlrSF        0.281986      0.240379    0.339850    0.445863    0.097117
# 2ndFlrSF        0.010308      0.140024    0.173800   -0.137079   -0.099260
# LowQualFinSF   -0.183784     -0.062419   -0.068628   -0.064503    0.014807
# GrLivArea       0.199010      0.287389    0.388052    0.208171   -0.009640
# BsmtFullBath    0.187599      0.119470    0.083010    0.649212    0.158678
# BsmtHalfBath   -0.038162     -0.012337    0.027403    0.067418    0.070948
# FullBath        0.468271      0.439046    0.272999    0.058543   -0.076444
# HalfBath        0.242656      0.183331    0.199108    0.004262   -0.032148
# BedroomAbvGr   -0.070651     -0.040581    0.102775   -0.107355   -0.015728
# KitchenAbvGr   -0.174800     -0.149598   -0.038450   -0.081007   -0.040751
# TotRmsAbvGrd    0.095589      0.191740    0.279568    0.044316   -0.035227
# Fireplaces      0.147716      0.112581    0.247015    0.260011    0.046921
# GarageYrBlt     0.272029      0.146357    0.132696    0.115843    0.035070
# GarageCars      0.537850      0.420622    0.361945    0.224054   -0.038264
# GarageArea      0.478954      0.371600    0.370884    0.296970   -0.018227
# WoodDeckSF      0.224880      0.205726    0.159991    0.204306    0.067898
# OpenPorchSF     0.188686      0.226298    0.122528    0.111761    0.003093
# EnclosedPorch  -0.387268     -0.193919   -0.109907   -0.102303    0.036543
# 3SsnPorch       0.031355      0.045286    0.019144    0.026451   -0.029993
# ScreenPorch    -0.050364     -0.038740    0.062248    0.062021    0.088871
# PoolArea        0.004950      0.005829    0.011928    0.140491    0.041709
# MiscVal        -0.034383     -0.010286   -0.029512    0.003571    0.004940
# MoSold          0.012398      0.021490   -0.006723   -0.015727   -0.015211
# YrSold         -0.013618      0.035743   -0.008317    0.014359    0.031706
# SalePrice       0.514408      0.507831    0.460535    0.362874   -0.010151
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# MSSubClass     ...   -0.012579    -0.006100      -0.012037  -0.043825
# LotFrontage    ...    0.075542     0.137014       0.010287   0.061945
# LotArea        ...    0.171698     0.084774      -0.018340   0.020423
# OverallQual    ...    0.238923     0.308819      -0.113937   0.030371
# OverallCond    ...   -0.003334    -0.032589       0.070356   0.025504
# YearBuilt      ...    0.224880     0.188686      -0.387268   0.031355
# YearRemodAdd   ...    0.205726     0.226298      -0.193919   0.045286
# MasVnrArea     ...    0.159991     0.122528      -0.109907   0.019144
# BsmtFinSF1     ...    0.204306     0.111761      -0.102303   0.026451
# BsmtFinSF2     ...    0.067898     0.003093       0.036543  -0.029993
# BsmtUnfSF      ...   -0.005316     0.129005      -0.002538   0.020764
# TotalBsmtSF    ...    0.232019     0.247264      -0.095478   0.037384
# 1stFlrSF       ...    0.235459     0.211671      -0.065292   0.056104
# 2ndFlrSF       ...    0.092165     0.208026       0.061989  -0.024358
# LowQualFinSF   ...   -0.025444     0.018251       0.061081  -0.004296
# GrLivArea      ...    0.247433     0.330224       0.009113   0.020643
# BsmtFullBath   ...    0.175315     0.067341      -0.049911  -0.000106
# BsmtHalfBath   ...    0.040161    -0.025324      -0.008555   0.035114
# FullBath       ...    0.187703     0.259977      -0.115093   0.035353
# HalfBath       ...    0.108080     0.199740      -0.095317  -0.004972
# BedroomAbvGr   ...    0.046854     0.093810       0.041570  -0.024478
# KitchenAbvGr   ...   -0.090130    -0.070091       0.037312  -0.024600
# TotRmsAbvGrd   ...    0.165984     0.234192       0.004151  -0.006683
# Fireplaces     ...    0.200019     0.169405      -0.024822   0.011257
# GarageYrBlt    ...    0.117305     0.049877      -0.076822   0.029401
# GarageCars     ...    0.226342     0.213569      -0.151434   0.035765
# GarageArea     ...    0.224666     0.241435      -0.121777   0.035087
# WoodDeckSF     ...    1.000000     0.058661      -0.125989  -0.032771
# OpenPorchSF    ...    0.058661     1.000000      -0.093079  -0.005842
# EnclosedPorch  ...   -0.125989    -0.093079       1.000000  -0.037305
# 3SsnPorch      ...   -0.032771    -0.005842      -0.037305   1.000000
# ScreenPorch    ...   -0.074181     0.074304      -0.082864  -0.031436
# PoolArea       ...    0.073378     0.060762       0.054203  -0.007992
# MiscVal        ...   -0.009551    -0.018584       0.018361   0.000354
# MoSold         ...    0.021011     0.071255      -0.028887   0.029474
# YrSold         ...    0.022270    -0.057619      -0.009916   0.018645
# SalePrice      ...    0.315444     0.339500      -0.115004   0.060119
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSSubClass       -0.026030  0.008283 -0.007683 -0.013585 -0.021407  -0.060775
# LotFrontage       0.037655  0.180819 -0.000255  0.010451  0.006380   0.323828
# LotArea           0.043160  0.077672  0.038068  0.001205 -0.014261   0.249499
# OverallQual       0.064886  0.065166 -0.031406  0.070815 -0.027347   0.789185
# OverallCond       0.054811 -0.001985  0.068777 -0.003511  0.043950  -0.065642
# YearBuilt        -0.050364  0.004950 -0.034383  0.012398 -0.013618   0.514408
# YearRemodAdd     -0.038740  0.005829 -0.010286  0.021490  0.035743   0.507831
# MasVnrArea        0.062248  0.011928 -0.029512 -0.006723 -0.008317   0.460535
# BsmtFinSF1        0.062021  0.140491  0.003571 -0.015727  0.014359   0.362874
# BsmtFinSF2        0.088871  0.041709  0.004940 -0.015211  0.031706  -0.010151
# BsmtUnfSF        -0.012579 -0.035092 -0.023837  0.034888 -0.041258   0.215724
# TotalBsmtSF       0.084489  0.126053 -0.018479  0.013196 -0.014969   0.595042
# 1stFlrSF          0.088758  0.131525 -0.021096  0.031372 -0.013604   0.587642
# 2ndFlrSF          0.040606  0.081487  0.016197  0.035164 -0.028700   0.330386
# LowQualFinSF      0.026799  0.062157 -0.003793 -0.022174 -0.028921  -0.032381
# GrLivArea         0.101510  0.170205 -0.002416  0.050240 -0.036526   0.707300
# BsmtFullBath      0.023148  0.067616 -0.023047 -0.025361  0.067049   0.212924
# BsmtHalfBath      0.032121  0.020025 -0.007367  0.032873 -0.046524  -0.011109
# FullBath         -0.008106  0.049604 -0.014290  0.055872 -0.019669   0.554988
# HalfBath          0.072426  0.022381  0.001290 -0.009050 -0.010269   0.295592
# BedroomAbvGr      0.044300  0.070703  0.007767  0.046544 -0.036014   0.158281
# KitchenAbvGr     -0.051613 -0.014525  0.062341  0.026589  0.031687  -0.132108
# TotRmsAbvGrd      0.059383  0.083757  0.024763  0.036907 -0.034516   0.528363
# Fireplaces        0.184530  0.095074  0.001409  0.046357 -0.024096   0.459611
# GarageYrBlt       0.061416  0.015858 -0.006669  0.019151 -0.011134   0.265622
# GarageCars        0.050494  0.020934 -0.043080  0.040522 -0.039117   0.628329
# GarageArea        0.051412  0.061047 -0.027400  0.027974 -0.027378   0.619000
# WoodDeckSF       -0.074181  0.073378 -0.009551  0.021011  0.022270   0.315444
# OpenPorchSF       0.074304  0.060762 -0.018584  0.071255 -0.057619   0.339500
# EnclosedPorch    -0.082864  0.054203  0.018361 -0.028887 -0.009916  -0.115004
# 3SsnPorch        -0.031436 -0.007992  0.000354  0.029474  0.018645   0.060119
# ScreenPorch       1.000000  0.051307  0.031946  0.023217  0.010694   0.100284
# PoolArea          0.051307  1.000000  0.029669 -0.033737 -0.059689   0.103280
# MiscVal           0.031946  0.029669  1.000000 -0.006495  0.004906  -0.013071
# MoSold            0.023217 -0.033737 -0.006495  1.000000 -0.145721   0.072764
# YrSold            0.010694 -0.059689  0.004906 -0.145721  1.000000  -0.045508
# SalePrice         0.100284  0.103280 -0.013071  0.072764 -0.045508   1.000000
#
# [37 rows x 37 columns]

# %%
plt.figure(figsize=[30,20])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# We can notice that KitchenAbvGr is some what negatively correlated with SalePrice column when compared with other columns. Most of the columns are positively correlated with salesprice columns like: OverallQual,YearBlt,YearRemodelAdd,FullBath,GarageCars

# %%
df_concat.select_dtypes(include=['int64','float'])
#pd.set_option('display.max_columns',None)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0            120         69.0     4928            6            5       1976
# 1             20         95.0    15865            8            6       1970
# 2             60         92.0     9920            7            5       1996
# 3             20        105.0    11751            6            6       1977
# 4             20         69.0    16635            6            7       1977
# ...          ...          ...      ...          ...          ...        ...
# 1455          20         78.0    10206            8            5       2007
# 1456          20         57.0     9245            5            5       1994
# 1457          20         69.0    11241            6            7       1970
# 1458          50         50.0     5000            6            7       1947
# 1459         160         21.0     1953            6            5       1973
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0             1976         0.0         120           0  ...           0
# 1             1970         0.0         351         823  ...          81
# 2             1997         0.0         862           0  ...         180
# 3             1977       480.0         705           0  ...           0
# 4             2000       126.0        1246           0  ...         240
# ...            ...         ...         ...         ...  ...         ...
# 1455          2007       468.0          33           0  ...         144
# 1456          1995         0.0         686           0  ...           0
# 1457          1970       180.0         578           0  ...           0
# 1458          1950         0.0         399           0  ...           0
# 1459          1973       408.0         309           0  ...          72
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 0             205              0          0            0         0        0
# 1             207              0          0          224         0        0
# 2             130              0          0            0         0        0
# 3             122              0          0            0         0        0
# 4               0              0          0            0         0        0
# ...           ...            ...        ...          ...       ...      ...
# 1455           99              0          0            0         0        0
# 1456            0              0          0            0         0        0
# 1457            0              0          0            0         0      700
# 1458           24             36          0            0         0        0
# 1459            0              0          0            0         0        0
#
#       MoSold  YrSold  SalePrice
# 0          2    2007   128000.0
# 1         10    2007   268000.0
# 2          6    2007   269790.0
# 3          1    2010   190000.0
# 4          6    2009   215000.0
# ...      ...     ...        ...
# 1455      10    2008        NaN
# 1456       2    2008        NaN
# 1457       3    2010        NaN
# 1458      10    2006        NaN
# 1459       6    2006        NaN
#
# [1460 rows x 37 columns]

# %%
df_concat.select_dtypes(include=['object'])
#pd.set_option('display.max_columns',None)
# Out:
#      MSZoning LotShape LandContour LotConfig LandSlope Neighborhood  \
# 0          RL      IR1         Lvl    Inside       Gtl      NPkVill
# 1          RL      IR1         Lvl    Inside       Mod        NAmes
# 2          RL      IR1         Lvl   CulDSac       Gtl      NoRidge
# 3          RL      IR1         Lvl    Inside       Gtl       NWAmes
# 4          RL      IR1         Lvl       FR2       Gtl       NWAmes
# ...       ...      ...         ...       ...       ...          ...
# 1455       RL      Reg         Lvl    Inside       Gtl      Somerst
# 1456       RL      IR2         Lvl    Inside       Gtl      CollgCr
# 1457       RL      IR1         Lvl   CulDSac       Gtl        NAmes
# 1458       RM      Reg         Lvl    Corner       Gtl      BrkSide
# 1459       RM      Reg         Lvl    Inside       Gtl       BrDale
#
#      Condition1 Condition2 BldgType HouseStyle  ... Functional FireplaceQu  \
# 0          Norm       Norm   TwnhsE     1Story  ...        Typ          TA
# 1          Norm       Norm     1Fam     1Story  ...        Typ          TA
# 2          Norm       Norm     1Fam     2Story  ...        Typ          TA
# 3          Norm       Norm     1Fam     1Story  ...        Typ          TA
# 4          Norm       Norm     1Fam     1Story  ...        Typ          TA
# ...         ...        ...      ...        ...  ...        ...         ...
# 1455       Norm       Norm     1Fam     1Story  ...        Typ          Gd
# 1456       Norm       Norm     1Fam     1Story  ...        Typ          Gd
# 1457       Norm       Norm     1Fam     1Story  ...        Typ          TA
# 1458      Feedr       Norm     1Fam     1.5Fin  ...        Typ          Gd
# 1459       Norm       Norm    Twnhs     2Story  ...        Typ          Gd
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 0        Attchd          RFn         TA         TA          Y       WD
# 1        Attchd          Unf         TA         TA          Y       WD
# 2        Attchd          Unf         TA         TA          Y       WD
# 3        Attchd          RFn         TA         TA          Y      COD
# 4        Attchd          Fin         TA         TA          Y       WD
# ...         ...          ...        ...        ...        ...      ...
# 1455     Attchd          RFn         TA         TA          Y       WD
# 1456     Detchd          Unf         TA         TA          Y       WD
# 1457     Attchd          Fin         TA         TA          Y       WD
# 1458     Detchd          Unf         TA         TA          Y       WD
# 1459     Detchd          Unf         TA         TA          Y       WD
#
#      SaleCondition dataset_type
# 0           Normal        Train
# 1           Normal        Train
# 2           Normal        Train
# 3           Normal        Train
# 4           Normal        Train
# ...            ...          ...
# 1455        Normal         Test
# 1456        Normal         Test
# 1457        Normal         Test
# 1458        Normal         Test
# 1459        Normal         Test
#
# [1460 rows x 38 columns]

# %% [markdown]
# Some of the columns here we can see that they are having some kind of order and hence it is ordinal in nature

# %%
df_concat['LandSlope'] = df_concat.LandSlope.map({'Gtl':0,'Mod':1,'Sev':2})
df_concat['ExterQual'] = df_concat.ExterQual.map({'Po':0,'Fa':1,'TA':2,'Gd':3,'Ex':4})
df_concat['BsmtQual'] = df_concat.BsmtQual.map({'NA':0,'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5})
df_concat['BsmtCond'] = df_concat.BsmtCond.map({'NA':0,'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5})
df_concat['BsmtExposure'] = df_concat.BsmtExposure.map({'NA':0,'No':1,'Mn':2,'Av':3,'Gd':4})
df_concat['BsmtFinType1'] = df_concat.BsmtFinType1.map({'NA':0,'Unf':1,'LwQ':2,'Rec':3,'BLQ':4,'ALQ':5,'GLQ':6})
df_concat['BsmtFinType2'] = df_concat.BsmtFinType2.map({'NA':0,'Unf':1,'LwQ':2,'Rec':3,'BLQ':4,'ALQ':5,'GLQ':6})
df_concat['HeatingQC'] = df_concat.HeatingQC.map({'Po':0,'Fa':1,'TA':2,'Gd':3,'Ex':4})
df_concat['CentralAir'] = df_concat.CentralAir.map({'N':0,'Y':1})
df_concat['KitchenQual'] = df_concat.KitchenQual.map({'Po':0,'Fa':1,'TA':2,'Gd':3,'Ex':4})
df_concat['GarageFinish'] = df_concat.GarageFinish.map({'NA':0,'Unf':1,'RFn':2,'Fin':3})
df_concat['GarageQual'] = df_concat.GarageQual.map({'NA':0,'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5})
df_concat['GarageCond'] = df_concat.GarageCond.map({'NA':0,'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5})
df_concat['ExterCond'] = df_concat.ExterCond.map({'Po':0,'Fa':1,'TA':2,'Gd':3,'Ex':4})
df_concat['LotShape'] = df_concat.LotShape.map({'IR1':0,'IR2':1,'IR3':2,'Reg':3})
df_concat['FireplaceQu'] = df_concat.FireplaceQu.map({'Po':0,'Fa':1,'TA':2,'Gd':3,'Ex':4})
df_concat['dataset_type'] = df_concat.dataset_type.map({'Train':0,'Test':1})

# %%
balance_object = df_concat.filter(['MSZoning','LandContour','LotConfig','Neighborhood','Condition1','Condition2','BldgType',
             'HouseStyle','RoofStyle','RoofMatl','Exterior1st',  'Exterior2nd','MasVnrType','Foundation',
             'Heating','Electrical','Functional','GarageType','PavedDrive','SaleType','SaleCondition'], axis=1)
balance_object
# Out:
#      MSZoning LandContour LotConfig Neighborhood Condition1 Condition2  \
# 0          RL         Lvl    Inside      NPkVill       Norm       Norm
# 1          RL         Lvl    Inside        NAmes       Norm       Norm
# 2          RL         Lvl   CulDSac      NoRidge       Norm       Norm
# 3          RL         Lvl    Inside       NWAmes       Norm       Norm
# 4          RL         Lvl       FR2       NWAmes       Norm       Norm
# ...       ...         ...       ...          ...        ...        ...
# 1455       RL         Lvl    Inside      Somerst       Norm       Norm
# 1456       RL         Lvl    Inside      CollgCr       Norm       Norm
# 1457       RL         Lvl   CulDSac        NAmes       Norm       Norm
# 1458       RM         Lvl    Corner      BrkSide      Feedr       Norm
# 1459       RM         Lvl    Inside       BrDale       Norm       Norm
#
#      BldgType HouseStyle RoofStyle RoofMatl  ... Exterior2nd MasVnrType  \
# 0      TwnhsE     1Story     Gable  CompShg  ...     Plywood       None
# 1        1Fam     1Story      Flat  Tar&Grv  ...     Wd Sdng       None
# 2        1Fam     2Story     Gable  CompShg  ...     MetalSd       None
# 3        1Fam     1Story       Hip  CompShg  ...     Plywood    BrkFace
# 4        1Fam     1Story     Gable  CompShg  ...     CmentBd      Stone
# ...       ...        ...       ...      ...  ...         ...        ...
# 1455     1Fam     1Story     Gable  CompShg  ...     VinylSd      Stone
# 1456     1Fam     1Story     Gable  CompShg  ...     VinylSd       None
# 1457     1Fam     1Story     Gable  CompShg  ...     Wd Sdng    BrkFace
# 1458     1Fam     1.5Fin     Gable  CompShg  ...     CmentBd       None
# 1459    Twnhs     2Story     Gable  CompShg  ...     HdBoard    BrkFace
#
#      Foundation Heating Electrical Functional GarageType PavedDrive SaleType  \
# 0        CBlock    GasA      SBrkr        Typ     Attchd          Y       WD
# 1         PConc    GasA      SBrkr        Typ     Attchd          Y       WD
# 2         PConc    GasA      SBrkr        Typ     Attchd          Y       WD
# 3        CBlock    GasA      SBrkr        Typ     Attchd          Y      COD
# 4        CBlock    GasA      SBrkr        Typ     Attchd          Y       WD
# ...         ...     ...        ...        ...        ...        ...      ...
# 1455      PConc    GasA      SBrkr        Typ     Attchd          Y       WD
# 1456      PConc    GasA      SBrkr        Typ     Detchd          Y       WD
# 1457     CBlock    GasA      SBrkr        Typ     Attchd          Y       WD
# 1458     CBlock    GasA      SBrkr        Typ     Detchd          Y       WD
# 1459     CBlock    GasA      SBrkr        Typ     Detchd          Y       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3           Normal
# 4           Normal
# ...            ...
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [1460 rows x 21 columns]

# %% [markdown]
# Some of the object columns can be transformed directly in below steps as ordinal columns are transformed above already

# %%
LE=LabelEncoder()
for column in balance_object:
    df_concat.loc[:,column] = LE.fit_transform(df_concat.loc[:,column])
df_concat
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0            120         3         69.0     4928         0            3
# 1             20         3         95.0    15865         0            3
# 2             60         3         92.0     9920         0            3
# 3             20         3        105.0    11751         0            3
# 4             20         3         69.0    16635         0            3
# ...          ...       ...          ...      ...       ...          ...
# 1455          20         3         78.0    10206         3            3
# 1456          20         3         57.0     9245         1            3
# 1457          20         3         69.0    11241         0            3
# 1458          50         4         50.0     5000         3            3
# 1459         160         4         21.0     1953         3            3
#
#       LotConfig  LandSlope  Neighborhood  Condition1  ...  3SsnPorch  \
# 0             4          0            13           2  ...          0
# 1             4          1            12           2  ...          0
# 2             1          0            15           2  ...          0
# 3             4          0            14           2  ...          0
# 4             2          0            14           2  ...          0
# ...         ...        ...           ...         ...  ...        ...
# 1455          4          0            21           2  ...          0
# 1456          4          0             5           2  ...          0
# 1457          1          0            12           2  ...          0
# 1458          0          0             3           1  ...          0
# 1459          4          0             2           2  ...          0
#
#       ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 0               0         0        0       2    2007         8              4
# 1             224         0        0      10    2007         8              4
# 2               0         0        0       6    2007         8              4
# 3               0         0        0       1    2010         0              4
# 4               0         0        0       6    2009         8              4
# ...           ...       ...      ...     ...     ...       ...            ...
# 1455            0         0        0      10    2008         8              4
# 1456            0         0        0       2    2008         8              4
# 1457            0         0      700       3    2010         8              4
# 1458            0         0        0      10    2006         8              4
# 1459            0         0        0       6    2006         8              4
#
#       SalePrice  dataset_type
# 0      128000.0             0
# 1      268000.0             0
# 2      269790.0             0
# 3      190000.0             0
# 4      215000.0             0
# ...         ...           ...
# 1455        NaN             1
# 1456        NaN             1
# 1457        NaN             1
# 1458        NaN             1
# 1459        NaN             1
#
# [1460 rows x 75 columns]

# %% [markdown]
# ## Binning :

# %%
#Binning:
bins = [1860,1875,1890,1905,1920,1935,1950,1965,1980,1995,2010]
labels = [i for i in range(10)]
df_concat['YearBuilt'] = pd.cut(df_concat['YearBuilt'], bins=bins, labels=labels, include_lowest=True)

# %%
df_concat['YearBuilt'] = df_concat['YearBuilt'].astype(int)

# %%
#Binning:
bins = [0,1875,1890,1905,1920,1935,1950,1965,1980,1995,2010]
labels = [i for i in range(10)]
df_concat['GarageYrBlt'] = pd.cut(df_concat['GarageYrBlt'], bins=bins, labels=labels, include_lowest=True)

# %%
df_concat['GarageYrBlt']= df_concat['GarageYrBlt'].astype(int)

# %%
#Binning:
bins = [0,2006,2007,2008,2009,2010]
labels = [i for i in range(5)]
df_concat['YrSold'] = pd.cut(df_concat['YrSold'], bins=bins, labels=labels, include_lowest=True)

# %%
df_concat['YrSold']= df_concat['YrSold'].astype(int)

# %% [markdown]
# Binning has been done for some of the Year columns so as to get good fit for model building and reduce the count and ranges

# %% [markdown]
# ## Lets Check Outliers with Box Plot :

# %%
df_concat.iloc[:,0:20].boxplot(figsize=[18,8])
plt.subplots_adjust(bottom=0.25)
plt.xticks(rotation=90)
plt.show()

# %%
df_concat.iloc[:,20:40].boxplot(figsize=[18,8])
plt.subplots_adjust(bottom=0.25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# df_concat.iloc[:,40:60].boxplot(figsize=[18,8]) plt.subplots_adjust(bottom=0.25) plt.xticks(rotation=90) plt.show()

# %%
df_concat.iloc[:,60:73].boxplot(figsize=[18,8])
plt.subplots_adjust(bottom=0.25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can notice that there are some columns having outliers like MiscVal,GrLiveArea,LowQualityFinSF,GarageArea,TotalBsmtSF,LotArea,MasVsrArea,1stFlrSF,

# %% [markdown]
# ## Outlier Removal:

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_concat))
df_zscore=df_concat[(z<3).all(axis=1)]

# %%
df_zscore.shape
# Out:
# (0, 75)

# %% [markdown]
# When tried to remove outlier data is skewed. so lets proceed with the outliers

# %%
df_concat.describe()
# Out:
#         MSSubClass     MSZoning  LotFrontage        LotArea     LotShape  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean     56.897260     3.028767    69.863699   10516.828082     1.942466
# std      42.300571     0.632017    22.027677    9981.264932     1.409156
# min      20.000000     0.000000    21.000000    1300.000000     0.000000
# 25%      20.000000     3.000000    60.000000    7553.500000     0.000000
# 50%      50.000000     3.000000    69.000000    9478.500000     3.000000
# 75%      70.000000     3.000000    79.000000   11601.500000     3.000000
# max     190.000000     4.000000   313.000000  215245.000000     3.000000
#
#        LandContour    LotConfig    LandSlope  Neighborhood   Condition1  ...  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000  ...
# mean      2.777397     3.019178     0.062329     12.251370     2.031507  ...
# std       0.707666     1.622634     0.276232      6.013735     0.868515  ...
# min       0.000000     0.000000     0.000000      0.000000     0.000000  ...
# 25%       3.000000     2.000000     0.000000      7.000000     2.000000  ...
# 50%       3.000000     4.000000     0.000000     12.000000     2.000000  ...
# 75%       3.000000     4.000000     0.000000     17.000000     2.000000  ...
# max       3.000000     4.000000     2.000000     24.000000     8.000000  ...
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      3.409589    15.060959     2.758904     43.489041     6.321918
# std      29.317331    55.757415    40.177307    496.123024     2.703626
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     5.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     508.000000   480.000000   738.000000  15500.000000    12.000000
#
#             YrSold     SaleType  SaleCondition      SalePrice  dataset_type
# count  1460.000000  1460.000000    1460.000000    1168.000000   1460.000000
# mean      1.815753     7.513014       3.770548  181477.005993      0.200000
# std       1.328095     1.552100       1.100854   79105.586863      0.400137
# min       0.000000     0.000000       0.000000   34900.000000      0.000000
# 25%       1.000000     8.000000       4.000000  130375.000000      0.000000
# 50%       2.000000     8.000000       4.000000  163995.000000      0.000000
# 75%       3.000000     8.000000       4.000000  215000.000000      0.000000
# max       4.000000     8.000000       5.000000  755000.000000      1.000000
#
# [8 rows x 75 columns]

# %%
#Lets seprate the train and test
df_newtrain=df_concat.loc[df_concat["dataset_type"]==0]
df_newtest=df_concat.loc[df_concat["dataset_type"]==1]

# %% [markdown]
# Splitting of the dataset with TEST and TRAIN datas after data handlings in above steps

# %%
#Lets drop the SalePrice from test dataset as that is the o/p variable that needs to be predicted
df_newtest.drop(columns=["SalePrice"],inplace=True)

# %%
#lets drop "dataset_type" column from df_newtrain and df_newtest
df_newtrain.drop(columns=["dataset_type"],inplace=True)
df_newtest.drop(columns=["dataset_type"],inplace=True)

# %% [markdown]
# ## Feature Selection:

# %%
#seprating input and output from df_newtrain
x=df_newtrain.drop(columns=["SalePrice"])
y=df_newtrain[["SalePrice"]]

# %% [markdown]
# Splitting of Independent and dependent variables.Observation: In the above block of codes we have split the datset which was earlier concatinated in start. Now we need to do x,y split so we have done train and test datset split and x,y split for model process

# %% [markdown]
# ## Skewness removal and Standardisation:

# %%
from sklearn.preprocessing import power_transform
df_skew=power_transform(x)
df_skew=pd.DataFrame(df_skew,columns=x.columns)

# %%
x=df_skew

# %%
x.shape
# Out:
# (1168, 73)

# %%
y.shape
# Out:
# (1168, 1)

# %% [markdown]
# ## Best Random State Checking:

# %%
maximum_accuracy=0
maximum_randomstate=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
 #  acc=accuracy_score(y_test,pred)
    acc=(r2_score(y_test,pred))
    if acc>maximum_accuracy:
        maximum_accuracy=acc
        maximum_randomstate=i
print("Best accuracy is  "  ,maximum_accuracy , "  at random_state:", maximum_randomstate)
# Out:
# Best accuracy is   0.8722552955344898   at random_state: 140

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=maximum_randomstate)

# %% [markdown]
# ## Model Building:

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)
print("Coefficient : ",lm.coef_)
print("Intercept   : ",lm.intercept_)
print("Score       : ",lm.score(x_train,y_train))
print(' ')
print("error")
print("Mean absolute error    :",mean_absolute_error(y_test,pred))
print("Mean squared error     :",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
print(' ')
#r2 score ------> coefficient of determination
#i.e. change coming in y whenever x is being changed.
from sklearn.metrics import r2_score
print("r2 score : ",r2_score(y_test,pred))
# Out:
# Coefficient :  [[-3151.07598028  1145.96210458  -258.88705206  3425.20028503
#    -465.11911431  1818.42813904  -519.76132442  1354.75583608
#    2600.44116265  -639.4006137  -2108.88411538 -3147.12948605
#   -1376.34167465 15212.20794165  4526.27241383  3603.26070011
#    1804.88246633  6697.83724543 12375.34015438 -1173.76774436
#   -2025.797169    1602.40994603   253.52333191  4235.37462234
#   -1722.95201348  3184.5593824   6763.58030552  -176.10190594
#    4190.16010672  2652.93942408   369.00052475  -409.81705604
#   -2417.03138594 -7226.46180689 12823.97011704 -1329.39291345
#    3348.45639644 -1784.73923895 -2867.92770521  2713.44175824
#    1303.70848294 -1083.8531473  14356.33758507  1033.1883771
#    -321.04597222  6685.10083733  6119.35814974 -3536.88694177
#   -1972.02531891  4713.29383158  5249.22176424  3164.03477194
#    5989.98316183  4782.2171362   2634.5430486  -5827.01441865
#      19.02410334  9012.39233668  1655.61869759  1964.8221315
#    1627.52521115 -1156.21829399  1202.22086918  -297.26829273
#     394.6516504    382.10752043  1293.16690505  2656.10910175
#     830.03149716 -1918.75932282  -864.66953041 -1957.12264526
#    2529.63180144]]
# Intercept   :  [181574.30137098]
# Score       :  0.821323424562247
#
# error
# Mean absolute error    : 19707.5060807038
# Mean squared error     : 691757925.8268418
# Root mean squared error: 26301.291333826972
#
# r2 score :  0.8722552955344898

# %%
rd=Ridge(alpha=0.0001)# to minimize the coefficient varience
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
rd.score(x_train,y_train)
print("Coefficient : ",rd.coef_)
print("Intercept   : ",rd.intercept_)
print("Score       : ",rd.score(x_train,y_train))
print(' ')
print("error")
print("Mean absolute error    :",mean_absolute_error(y_test,pred))
print("Mean squared error     :",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
print(' ')
#r2 score ------> coefficient of determination
#i.e. change coming in y whenever x is being changed.
from sklearn.metrics import r2_score
print("r2 score : ",r2_score(y_test,pred))
# Out:
# Coefficient :  [[-3151.07801098  1145.96247367  -258.88678585  3425.20142726
#    -465.11942902  1818.42724521  -519.76172214  1354.75541203
#    2600.44134884  -639.40067469 -2108.88345384 -3147.12619685
#   -1376.33807684 15212.20694321  4526.27076021  3603.25857227
#    1804.88211382  6697.83656626 12375.33827829 -1173.76858562
#   -2025.79553588  1602.41046066   253.52356661  4235.37553189
#   -1722.95169532  3184.55871763  6763.58148593  -176.10125648
#    4190.16056155  2652.93518702   369.01156563  -409.84367389
#   -2417.00249492 -7226.45017819 12823.95682224 -1329.39217342
#    3348.45653926 -1784.73904122 -2867.92680624  2713.46884941
#    1303.73102622 -1083.84908145 14356.30606604  1033.19010757
#    -321.04550764  6685.10148251  6119.35906948 -3536.88538196
#   -1972.02535507  4713.29451682  5249.22294202  3164.03495039
#    5989.98311258  4782.21681054  2634.54227809 -5827.01050436
#      19.0259817   9012.38727158  1655.62168872  1964.82165955
#    1627.524013   -1156.21822349  1202.22134519  -297.26725006
#     394.65192398   382.10710054  1293.16698636  2656.10943955
#     830.0307924  -1918.75900267  -864.6695237  -1957.1228073
#    2529.63182646]]
# Intercept   :  [181574.30131141]
# Score       :  0.8213234245622338
#
# error
# Mean absolute error    : 19707.504790146188
# Mean squared error     : 691757823.8804199
# Root mean squared error: 26301.289395777156
#
# r2 score :  0.8722553143606065

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
rf.score(x_train,y_train)
#print("Coefficient : ",rf.coef_)
# print("Intercept   : ",rf.intercept_)
print("Score       : ",rf.score(x_train,y_train))
print(' ')
print("error")
print("Mean absolute error    :",mean_absolute_error(y_test,pred))
print("Mean squared error     :",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
print(' ')
#r2 score ------> coefficient of determination
#i.e. change coming in y whenever x is being changed.
from sklearn.metrics import r2_score
print("r2 score : ",r2_score(y_test,pred))
# Out:
# Score       :  0.9761921118258018
#
# error
# Mean absolute error    : 17260.126025641028
# Mean squared error     : 627106579.0426568
# Root mean squared error: 25042.096139154502
#
# r2 score :  0.8841942511718557

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred=gbr.predict(x_test)
gbr.score(x_train,y_train)
#print("Coefficient : ",rf.coef_)
# print("Intercept   : ",rf.intercept_)
print("Score       : ",gbr.score(x_train,y_train))
print(' ')
print("error")
print("Mean absolute error    :",mean_absolute_error(y_test,pred))
print("Mean squared error     :",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
print(' ')
#r2 score ------> coefficient of determination
#i.e. change coming in y whenever x is being changed.
from sklearn.metrics import r2_score
print("r2 score : ",r2_score(y_test,pred))
# Out:
# Score       :  0.9719628188682605
#
# error
# Mean absolute error    : 15783.462607525518
# Mean squared error     : 522400252.97608155
# Root mean squared error: 22856.076937569174
#
# r2 score :  0.9035300306109656

# %%
adb=AdaBoostRegressor()
adb.fit(x_train,y_train)
pred=adb.predict(x_test)
adb.score(x_train,y_train)
print("Score       : ",adb.score(x_train,y_train))
print(' ')
print("error")
print("Mean absolute error    :",mean_absolute_error(y_test,pred))
print("Mean squared error     :",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
print(' ')
from sklearn.metrics import r2_score
print("r2 score : ",r2_score(y_test,pred))
# Out:
# Score       :  0.8757025297519281
#
# error
# Mean absolute error    : 24583.356290067033
# Mean squared error     : 1036759828.7247367
# Root mean squared error: 32198.75508035577
#
# r2 score :  0.8085449071452974

# %% [markdown]
# ## Pridiction:

# %%
#Pridict the value
pred=lm.predict(x_test)
print("Predicted Price : ", pred )
print("Actual Price :", y_test)
# Out:
# Predicted Price :  [[106557.2668304 ]
#  [224694.55618961]
#  [288445.33502928]
#  [148405.25912565]
#  [283694.58626807]
#  [228096.02049465]
#  [138853.73280966]
#  [385966.95433122]
#  [174742.27788743]
#  [139552.5338219 ]
#  [ 51874.88570371]
#  [144547.41290398]
#  [ 81781.32887163]
#  [203013.51599   ]
#  [299486.4931041 ]
#  [171756.53580063]
#  [270091.68763762]
#  [283362.60160748]
#  [179522.57904273]
#  [218851.31229815]
#  [115401.13184871]
#  [122131.30439628]
#  [290720.08909677]
#  [146345.96471812]
#  [338690.78649555]
#  [289778.61105061]
#  [118954.27490966]
#  [195439.95870162]
#  [160776.34700157]
#  [214268.40376313]
#  [128035.6062561 ]
#  [197412.5499496 ]
#  [ 59133.75904168]
#  [216621.23898044]
#  [168966.14024737]
#  [266199.26670023]
#  [-14766.16609175]
#  [268587.42769977]
#  [246467.72432046]
#  [108118.12897532]
#  [171842.90760323]
#  [198075.1404606 ]
#  [107035.2106959 ]
#  [212803.89639173]
#  [223967.76693818]
#  [238864.15390905]
#  [ 90770.24733472]
#  [316790.85699527]
#  [175360.32641181]
#  [ 79765.57920302]
#  [113418.61879624]
#  [211613.84932855]
#  [262769.18579696]
#  [119356.29831363]
#  [199863.2825848 ]
#  [253907.56042155]
#  [122804.52376325]
#  [209504.17194575]
#  [129557.250065  ]
#  [152738.95159815]
#  [119096.50393898]
#  [198984.84857315]
#  [110092.97272147]
#  [122690.36896836]
#  [340303.42548896]
#  [135382.16971724]
#  [123932.92076623]
#  [253647.50456916]
#  [201461.6195899 ]
#  [230561.154115  ]
#  [134923.65705651]
#  [194956.95399565]
#  [199762.59445525]
#  [291356.89769885]
#  [108614.33051279]
#  [235943.41646379]
#  [132142.46685865]
#  [208779.34807452]
#  [111021.77391575]
#  [240573.88875217]
#  [252699.56989883]
#  [166042.78908068]
#  [207604.56223996]
#  [200315.90851849]
#  [211219.00058425]
#  [171415.17081305]
#  [289079.0965097 ]
#  [308108.32981511]
#  [166277.41624252]
#  [ 29495.45627399]
#  [304993.69710482]
#  [243452.4558684 ]
#  [142831.62734499]
#  [158429.74106311]
#  [ 93845.62890491]
#  [290231.21093415]
#  [204496.81540909]
#  [328522.69897588]
#  [182261.16511969]
#  [201341.96195919]
#  [158423.88208755]
#  [175989.91761076]
#  [265483.57400048]
#  [274016.15802598]
#  [154037.97579455]
#  [160913.66274248]
#  [ 94077.75845899]
#  [151434.78093058]
#  [325324.09908022]
#  [213291.23959267]
#  [156455.11541782]
#  [ 92896.49007619]
#  [162847.04637996]
#  [379743.69614313]
#  [197346.18788419]
#  [123347.27049199]
#  [250374.43629844]
#  [126235.33712122]
#  [135757.8979446 ]
#  [213109.9072205 ]
#  [ 85529.36972671]
#  [399213.46550391]
#  [275166.75364818]
#  [149665.38664369]
#  [132350.06440704]
#  [220308.88606533]
#  [ 96916.99717124]
#  [171474.47779408]
#  [179437.8953286 ]
#  [124002.1803956 ]
#  [140447.59913481]
#  [171203.28402672]
#  [170742.11863402]
#  [158922.2982351 ]
#  [130981.25710291]
#  [224737.33534468]
#  [153632.61369503]
#  [281317.46317803]
#  [194475.08789009]
#  [105450.18028691]
#  [267806.44938463]
#  [254340.4449106 ]
#  [194103.44830282]
#  [141754.00496591]
#  [191377.88203119]
#  [111702.1321803 ]
#  [ 93751.49965463]
#  [102901.16100222]
#  [114685.58228725]
#  [267944.09965113]
#  [183284.62269006]
#  [159364.09068746]
#  [111669.75671548]
#  [199676.57702724]
#  [177427.67469791]
#  [215826.92371566]
#  [205396.61887734]
#  [137956.28719462]
#  [154618.21039825]
#  [259667.47551171]
#  [ 95441.23591683]
#  [199063.17413511]
#  [219168.09157982]
#  [265952.42196913]
#  [112270.1584718 ]
#  [156607.30766478]
#  [214439.49507912]
#  [222285.89104159]
#  [151328.97499633]
#  [218795.34269926]
#  [218919.17587636]
#  [297219.67655109]
#  [348000.18298688]
#  [200421.12931253]
#  [244227.73414451]
#  [105661.28181319]
#  [305543.38888959]
#  [171303.00884662]
#  [180834.73487958]
#  [157125.71931897]
#  [250482.97584727]
#  [ 79908.6979158 ]
#  [164032.3714134 ]
#  [219666.29675092]
#  [298828.77455416]
#  [ 82182.71929055]
#  [364907.92786874]
#  [110165.53151705]
#  [149381.29481087]
#  [ 88363.94599354]
#  [109088.41990609]
#  [155237.67627115]
#  [157529.00879307]
#  [208668.45679073]
#  [ 83245.18046772]
#  [127199.9524068 ]
#  [ 98811.9675798 ]
#  [151301.80197657]
#  [139246.85785018]
#  [260157.44236233]
#  [356772.58069346]
#  [228690.27910799]
#  [ 36969.39846746]
#  [222752.03734307]
#  [297555.88397639]
#  [222830.93443747]
#  [ 96860.40377682]
#  [204743.16087048]
#  [172642.77637761]
#  [101155.98015665]
#  [111299.34787626]
#  [ 92684.75630173]
#  [210197.78847467]
#  [165803.35248315]
#  [185490.89816863]
#  [220477.50859861]
#  [ 96064.64824378]
#  [257842.91041807]
#  [155256.61755094]
#  [127843.33056095]
#  [216639.00103313]
#  [303592.94117293]
#  [100747.54506586]
#  [102832.34367641]
#  [222671.65768921]
#  [130398.51980256]
#  [132055.80653759]
#  [187425.98573205]
#  [240122.56362525]
#  [180124.40004056]
#  [110352.19472268]
#  [207196.32203118]
#  [167392.38013661]
#  [252756.90895659]]
# Actual Price :       SalePrice
# 972    117000.0
# 1005   205000.0
# 666    305900.0
# 449    143250.0
# 30     319900.0
# ...         ...
# 843    154000.0
# 984    118500.0
# 628    174000.0
# 535    157900.0
# 194    246578.0
#
# [234 rows x 1 columns]

# %% [markdown]
# ## Cross Validation checking:

# %%
scr=cross_val_score(lm,x,y,cv=5,scoring="r2")
print("Cross Validation Score of LinearRegression Model is : ", scr.mean())
# Out:
# Cross Validation Score of LinearRegression Model is :  0.6941501614804562

# %%
scr=cross_val_score(rd,x,y,cv=5,scoring="r2")
print("Cross Validation Score of RidgeRegression Model is : ", scr.mean())
# Out:
# Cross Validation Score of RidgeRegression Model is :  0.6953426833322813

# %%
scr=cross_val_score(rf,x,y,cv=5,scoring="r2")
print("Cross Validation Score of RandomForestRegressor Model is : ", scr.mean())
# Out:
# Cross Validation Score of RandomForestRegressor Model is :  0.8504283611139059

# %%
scr=cross_val_score(gbr,x,y,cv=5,scoring='r2')
print("Cross Validation Score of GradientBoostingRegressor Model is : ", scr.mean())
# Out:
# Cross Validation Score of GradientBoostingRegressor Model is :  0.86679580377701

# %%
scr=cross_val_score(adb,x,y,cv=5,scoring="r2")
print("Cross Validation Score of AdaBoostRegressor Model is : ", scr.mean())
# Out:
# Cross Validation Score of AdaBoostRegressor Model is :  0.8005600434976344

# %% [markdown]
# ## Observation:
# Above various models shows that RandomForest and GradiantBooster Regressor are the best with good scores and R2 score values. So lets proceed with these 2 models for Hyper parameter tuning

# %% [markdown]
# ## Hyper Parameter tuning:

# %% [markdown]
# 1st Tuning:
#
# Random Forest Regressor

# %%
parameters={"bootstrap":[True,False], "criterion":["mse", "mae"],}

# %%
gcv=GridSearchCV(RandomForestRegressor(), parameters,cv=5,scoring='r2') #Tuning

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['mse', 'mae']},
#              scoring='r2')

# %%
gcv.best_params_
# Out:
# {'bootstrap': True, 'criterion': 'mae'}

# %%
mod=RandomForestRegressor(bootstrap= True, criterion='mae',random_state=maximum_randomstate)
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred)*100)
# Out:
# 88.8944037274142

# %% [markdown]
# 2nd Tuning:
#
# GradientBoosting Regressor

# %%
parameters = {'learning_rate': [0.01,0.02,0.03,0.04],
                  'subsample'    : [0.9, 0.5, 0.2, 0.1],
                  'n_estimators' : [100,500,1000, 1500]}

# %%
gcv=GridSearchCV(GradientBoostingRegressor(), parameters,cv=5,scoring="r2") #Tuning

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.02, 0.03, 0.04],
#                          'n_estimators': [100, 500, 1000, 1500],
#                          'subsample': [0.9, 0.5, 0.2, 0.1]},
#              scoring='r2')

# %%
gcv.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 500, 'subsample': 0.1}

# %%
mod2=GradientBoostingRegressor(learning_rate=0.04,n_estimators=100,subsample= 0.1,random_state=maximum_randomstate)
mod2.fit(x_train,y_train)
pred=mod2.predict(x_test)
print(r2_score(y_test,pred)*100)
# Out:
# 89.3167384509258

# %% [markdown]
# 3rd Tuning:
#
# Linear Regressor

# %%
#Linear Regression:
parameters={"fit_intercept":(True,False), "normalize":(False,True), "copy_X":(True,False)}

# %%
gcv=GridSearchCV(LinearRegression(), parameters,cv=5,scoring="r2") #Tuning

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': (True, False),
#                          'fit_intercept': (True, False),
#                          'normalize': (False, True)},
#              scoring='r2')

# %%
gcv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
mod3=LinearRegression(copy_X=True,fit_intercept=True,normalize=True)
mod3.fit(x_train,y_train)
pred=mod3.predict(x_test)
print(r2_score(y_test,pred)*100)
# Out:
# 87.22552955344898

# %% [markdown]
# ## Saving The Model:

# %%
import joblib
joblib.dump(mod2,"House_Sales_price.pkl")
# Out:
# ['House_Sales_price.pkl']

# %%
model=joblib.load("House_Sales_price.pkl")

# %%
prediction=model.predict(x_test)

# %%
print(r2_score(y_test,prediction)*100)
# Out:
# 89.3167384509258

# %%
prediction=pd.DataFrame(prediction) #Converting into Dataframe

# %%
prediction.to_csv('House_Sales_price.csv') #Saving the predictions

# %%
prediction
# Out:
#                  0
# 0    126499.734318
# 1    225877.786511
# 2    308251.523879
# 3    116206.002381
# 4    286380.574670
# ..             ...
# 229  147595.225402
# 230  122208.192225
# 231  215507.760685
# 232  153755.220100
# 233  235135.571662
#
# [234 rows x 1 columns]

# %% [markdown]
# ## Testing with the 2nd Dataset (Housing price_test)

# %%
df_newtest=x_test

# %%
x_test.shape
# Out:
# (234, 73)

# %%
mod=RandomForestRegressor(bootstrap= True, criterion='mae',random_state=maximum_randomstate)
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred)*100)
# Out:
# 88.8944037274142

# %% [markdown]
# ## Conclution & Observation:
#
# Hence we have got Best accuracy with GradientBoostingRegressor model. We have saved and loaded that for checking purpose and predicted in above steps.
